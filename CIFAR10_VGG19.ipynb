# %%
import numpy as np
import tensorflow as tf

# %%
def vgg_block(inputs,n_filters,dr,n_conv,lmd,mode):
    output = inputs
    for i in range(n_conv):
        output = tf.layers.conv2d(inputs=output,filters=n_filters,kernel_size=[3,3],padding='same',activation=tf.nn.relu,kernel_regularizer=tf.contrib.layers.l2_regularizer(lmd))
        output = tf.layers.batch_normalization(inputs=output,training=(mode==tf.estimator.ModeKeys.TRAIN))
        if i != n_conv-1:
            output = tf.layers.dropout(inputs=output,rate=dr,training=(mode==tf.estimator.ModeKeys.TRAIN))
    output = tf.layers.max_pooling2d(inputs=output,pool_size=[2,2],strides=2)
    return output

# %%
def vgg_net(features,labels,mode,params):
    x = features['x']
    for n_filters,n_conv,dr in params['network_def']:
        x = vgg_block(x,n_filters,dr,n_conv,params['regulariser'],mode)
    x = tf.layers.dropout(inputs=x,rate=0.5,training=(mode==tf.estimator.ModeKeys.TRAIN))
    x = tf.reshape(x,[-1,params['flat_size']])
    x = tf.layers.dense(inputs=x,units=params['fc1'],activation=tf.nn.relu,kernel_regularizer=tf.contrib.layers.l2_regularizer(params['regulariser']))
    x = tf.layers.batch_normalization(inputs=x,training=(mode==tf.estimator.ModeKeys.TRAIN))
    x = tf.layers.dropout(inputs=x,rate=0.5,training=(mode==tf.estimator.ModeKeys.TRAIN))
    
    logits = tf.layers.dense(inputs=x,units=params['n_classes'],activation=None)
        
    predictions = {
        'classes' : tf.argmax(logits,axis=1),
        'probabilities' : tf.nn.softmax(logits)
    }
    
    if mode == tf.estimator.ModeKeys.PREDICT:
        return tf.estimator.EstimatorSpec(predictions=predictions,mode=mode)
    
    loss = tf.losses.sparse_softmax_cross_entropy(labels=labels,logits=logits)

    if mode == tf.estimator.ModeKeys.TRAIN:
        global_step = tf.train.get_global_step()
        learning_rate = tf.train.exponential_decay(params['learning_rate'],global_step,128 * params['lr_drop'],0.5,staircase=True)
        optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
        update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)
        with tf.control_dependencies(update_ops):
            train_op = optimizer.minimize(loss=loss,global_step=global_step)
        return tf.estimator.EstimatorSpec(mode=mode,loss=loss,train_op=train_op)
    
    eval_ops = {
        'accuracy' : tf.metrics.accuracy(labels=labels,predictions=predictions['classes'])
    }
    return tf.estimator.EstimatorSpec(mode=mode,loss=loss,eval_metric_ops=eval_ops)

# %%
params = {
    'network_def' : [(64,2,0.3),(128,2,0.4),(256,3,0.4),(512,3,0.4),(512,3,0.4)],
    'flat_size' : 512,
    'fc1' : 512,
    'n_classes' : 10,
    'learning_rate' : 0.01,
    'lr_drop' : 20,
    'regulariser' : 0.0005
}
vgg19 = tf.estimator.Estimator(model_fn=vgg_net,params=params,model_dir='VGG16')
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': 'VGG16', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f042d0cfcf8>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
(x_train,y_train),(x_test,y_test) = tf.keras.datasets.cifar10.load_data()
x_train = np.asarray(x_train,dtype=np.float32)
x_test = np.asarray(x_test,dtype=np.float32)
y_train = np.asarray(y_train,dtype=np.int32)
y_test = np.asarray(y_test,dtype=np.int32)
mean = np.mean(x_train,axis=(0,1,2,3))
std = np.std(x_train,axis=(0,1,2,3))
x_train = (x_train - mean)/(std + 1e-7)
x_test = (x_test - mean)/(std + 1e-7)
x_test.shape
# Out:
# (10000, 32, 32, 3)

# %%
train_input = tf.estimator.inputs.numpy_input_fn(x={'x' : x_train},y=y_train,batch_size=128,num_epochs=None,shuffle=True)
vgg19.train(input_fn=train_input,steps=19200)
# Out:
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:
# INFO:tensorflow:step = 30401, loss = 0.052909244 (5.970 sec)
# INFO:tensorflow:global_step/sec: 16.7613
# INFO:tensorflow:step = 30501, loss = 0.18780059 (5.966 sec)
# INFO:tensorflow:global_step/sec: 16.7317
# INFO:tensorflow:step = 30601, loss = 0.07286473 (5.976 sec)
# INFO:tensorflow:global_step/sec: 16.7484
# INFO:tensorflow:step = 30701, loss = 0.014733963 (5.971 sec)
# INFO:tensorflow:global_step/sec: 16.8232
# INFO:tensorflow:step = 30801, loss = 0.011613811 (5.943 sec)
# INFO:tensorflow:global_step/sec: 16.7677
# INFO:tensorflow:step = 30901, loss = 0.008616919 (5.964 sec)
# INFO:tensorflow:global_step/sec: 16.7612
# INFO:tensorflow:step = 31001, loss = 0.018952938 (5.967 sec)
# INFO:tensorflow:global_step/sec: 16.8412
# INFO:tensorflow:step = 31101, loss = 0.09253895 (5.938 sec)
# INFO:tensorflow:global_step/sec: 16.7559
# INFO:tensorflow:step = 31201, loss = 0.036978625 (5.967 sec)
# INFO:tensorflow:global_step/sec: 16.7535
# INFO:tensorflow:step = 31301, loss = 0.06876722 (5.969 sec)
# INFO:tensorflow:global_step/sec: 16.7687
# INFO:tensorflow:step = 31401, loss = 0.08241085 (5.964 sec)
# INFO:tensorflow:global_step/sec: 16.7603
# INFO:tensorflow:step = 31501, loss = 0.01001727 (5.967 sec)
# INFO:tensorflow:global_step/sec: 16.8358
# INFO:tensorflow:step = 31601, loss = 0.0134379845 (5.939 sec)
# INFO:tensorflow:global_step/sec: 16.7385
# INFO:tensorflow:step = 31701, loss = 0.0062891506 (5.975 sec)
# INFO:tensorflow:global_step/sec: 16.7542
# INFO:tensorflow:step = 31801, loss = 0.019212207 (5.968 sec)
# INFO:tensorflow:global_step/sec: 16.7432
# INFO:tensorflow:step = 31901, loss = 0.04179009 (5.973 sec)
# INFO:tensorflow:Saving checkpoints for 32000 into VGG16/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.031683825.

# %%
eval_input = tf.estimator.inputs.numpy_input_fn(x={'x' : x_test},y=y_test,num_epochs=1,shuffle=False)
eval_results = vgg19.evaluate(input_fn=eval_input)
print(eval_results)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-06-23-09:39:21
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from VGG16/model.ckpt-32000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-06-23-09:39:25
# INFO:tensorflow:Saving dict for global step 32000: accuracy = 0.8844, global_step = 32000, loss = 0.5513622
# {'accuracy': 0.8844, 'loss': 0.5513622, 'global_step': 32000}

# %%
import matplotlib.pyplot as plt
from random import randint
from scipy.misc import toimage
num = randint(0,10000-1)
classes = ['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']
plt.imshow(toimage(x_test[num] * (std + 1e-7) + mean))
img = np.reshape(x_test[num],(1,32,32,3))
pred_fn = tf.estimator.inputs.numpy_input_fn({'x' : img},shuffle=False)
pred_res = vgg19.predict(input_fn=pred_fn)
result = next(pred_res)['classes']
print(classes[result])
if result == y_test[num]:
    print('Classification is accurate')
else:
    print('Classification is inaccurate')
# Out:
# INFO:tensorflow:Calling model_fn.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: DeprecationWarning: `toimage` is deprecated!
# `toimage` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use Pillow's ``Image.fromarray`` directly instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from VGG16/model.ckpt-32000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# cat
# Classification is accurate
